# %%
# print("Hi", 2, 3, sep=",", end="hehehe ")

# # 1*10^308
# print(1e308)

# multiline_str = """This is a multiline string with more than one line code.""" # when we have multiline string
# unicode = u"\U0001f600\U0001F606\U0001F923" # need to mention u in beginning for emoji
# raw_str = r"raw \n string" # r for raw string

# result = (n*(n+1)*(2*n + 1))/6 # sum of squares of first n natural numbers

# # keyword
# import keyword
# print(keyword.kwlist)

# import math
# math.sqrt(196)
# math.factorial(4)

# import random
# print(random.randint(1,100))

# # datetime
# import datetime
# print(datetime.datetime.now())

# # Else will always execute at end
# while x < 5:
#   print(x)
#   x += 1
# else:
#   print('limit crossed')

# for i in range(10):
#     if i%2==0:
#         continue
#     print(i) # skipped when if true

# # Loop runs only once
# for i in range(1, 10):
#     if i%2==0:
#         break
#     print(i)
        
# list(map(int, "1 2".split())) # map applies a function to a iterable


# # Finding prime using break and for
# lower = int(input('enter lower range'))
# upper = int(input('enter upper range'))

# for i in range(lower, upper+1):
#   for j in range(2, i):
#     if i%j == 0:
#     # This for loop is skipped
#       break
#   else:
#     print(i)

# %%
# # python characters are unicode which allow us to use many more characters, previously ascii where used which had limitations

# Creating Strings 
# s = '''hello'''
# s = """hello"""

# Accessing Strings
# s[::-1] # reverse
# s[6:0:-1] # reverse
# print(s[-6:-1])

# Adding Chars to Strings
# s = 'hello world'
# s = s + " hey"

# Editing Strings
# s[0] = 'H' # Error

# Deleting Strings
# del s # only entire string deletion possible

# Operations on Strings
# print('delhi' + ' ' + 'mumbai')
# print('delhi'*5)
# 'mumbai' > 'pune'


# String Functions
# len('hello world')
# max('hello world')
# min('hello world')
# sorted('hello world', reverse=True)

# s.capitalize()
# s.title()
# s.upper()
# s.lower()
# s.swapcase()

# 'my name is nitish'.count('i') # no error when count element not present
# 'my name is nitish'.find('x') # if not found -1
# 'my name is nitish'.index('x') # if not found error

# 'my name is nitish'.endswith('ish')
# 'my name is nitish'.startswith('1my')

# 'nitish1234'.isalnum()
# 'nitish'.isalpha()
# '123'.isdigit()
# 'first-name'.isidentifier()

# 'hi my name is nitish'.split()
# " ".join(['hi', 'my', 'name', 'is', 'nitish'])

# 'hi my name is nitish'.replace('nitish','campusx')
# 'nitish                           '.strip()

# '1234'.isnumeric()
